# %%
# !pip install kaggle
# Out:
# ...
# WARNING: Ignoring invalid distribution ~orch (D:\anaconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (D:\anaconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~orch (D:\anaconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (D:\anaconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~orch (D:\anaconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (D:\anaconda\Lib\site-packages)

# %%
import kagglehub

# %%
data = kagglehub.dataset_download("umar1103/suicide-sentiment-analysis-dataset")

print("Path to dataset files:", data)
