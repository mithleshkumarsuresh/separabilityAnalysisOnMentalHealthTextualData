# %%
import pandas as pd

# %%
metricsDf = pd.DataFrame.from_dict(
    {
        'TF-IDF' : [92, 92, 89, 91, 0.28442225623685213, 0.0010567652608167231],
        'word2vec':[88, 90, 90, 92, 0.22012008220452806, 0.2007835344831979],
        'FastText':[85, 87, 85, 89, 0.06635842834693313, 0.11741353784759165],
        'GloVe':[86, 87, 86, 89, 0.03877366592175619, 0.3929692578353779]
    },
    orient='index',
    columns=['Linear-SVM (Accuracy)', 'RBF-SVM (Accuracy)', 'Random Forest Classifier(Accuracy)', 'XGBoost Classifier(Accuracy)', 'KMeans ARI', 'KMeans Silhouette Score']
)

# %%
metricsDf.to_csv('metricsDf.csv')

# %%
metricsDf
# Out:
#           Linear-SVM (Accuracy)  RBF-SVM (Accuracy)  \
# TF-IDF                       92                  92
# word2vec                     88                  90
# FastText                     85                  87
# GloVe                        86                  87
#
#           Random Forest Classifier(Accuracy)  XGBoost Classifier(Accuracy)  \
# TF-IDF                                    89                            91
# word2vec                                  90                            92
# FastText                                  85                            89
# GloVe                                     86                            89
#
#           KMeans ARI  KMeans Silhouette Score
# TF-IDF      0.284422                 0.001057
# word2vec    0.220120                 0.200784
# FastText    0.066358                 0.117414
# GloVe       0.038774                 0.392969
